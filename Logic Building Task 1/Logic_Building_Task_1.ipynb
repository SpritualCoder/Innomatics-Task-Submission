# %%
# Program 1: User Login Check

# Stored credentials
correct_username = "admin"
correct_password = "1234"

# Taking input from user
username = input("Enter username: ")
password = input("Enter password: ")

# Checking credentials
if username == correct_username and password == correct_password:
    print("Login Successful")
else:
    print("Invalid Credentials")
# Out:
# Enter username: admin
# Enter password: 1234
# Login Successful

# %%
# Program 2: Pass / Fail Analyzer

marks = [45, 78, 90, 33, 60]

passCount = 0
failCount = 0

for mark in marks:
    if mark >= 50:
        passCount += 1
    else:
        failCount += 1

print("Pass / Fail Analysis:")
print("Total Students Passed:", passCount)
print("Total Students Failed:", failCount)
# Out:
# Pass / Fail Analysis:
# Total Students Passed: 3
# Total Students Failed: 2

# %%
# Program 3: Simple Data Cleaner

names = [" Alice ", "bob", " CHARLIE "]

# Modify the list
for i in range(len(names)):
    names[i] = names[i].strip().lower()

print("Cleaned Names:")
print(names)
# Out:
# Cleaned Names:
# ['alice', 'bob', 'charlie']

# %%
# Program 4: Message Length Analyzer

messages = ["Hi", "Welcome to the platform", "OK"]

for message in messages:
    length = len(message)
    print("Message:", message)
    print("Length:", length)

    if length > 10:
        print("This message is longer than 10 characters.")

    print()  # For spacing
# Out:
# Message: Hi
# Length: 2
#
# Message: Welcome to the platform
# Length: 23
# This message is longer than 10 characters.
#
# Message: OK
# Length: 2

# %%
# Program 5: Error Message Detector

logs = ["INFO", "ERROR", "WARNING", "ERROR"]

errorCount = 0

for log in logs:
    if log == "ERROR":
        errorCount += 1

print("Total ERROR entries:", errorCount)
# Out:
# Total ERROR entries: 2
